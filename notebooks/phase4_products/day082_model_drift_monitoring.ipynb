# %% [markdown]
# # Day 82: Model Drift Monitoring
#
# **Phase 4: End-to-End Products**
#
# ## Objective
# Monitoring de drift para modelos deportivos
#
# ## Task
# Implementar checks de data drift y model drift básicos: comparar distribución de features de entrenamiento vs datos recientes, tracking de métricas de modelo en producción por ventana temporal. Alertas simples.
#
# **Deliverable:** Script de monitoring + notebook de demo de drift detection.
#
# ---
#
# ### Instructions:
# *Treat this as your course workbook. Write your code, notes, or execution steps below.*
#
# Remember:
# - Document your decisions.
# - Use clear variable names.
# - If today's task involves creating a script in `src/`, a dashboard in `apps/`, or documentation in `docs/`, you can use this notebook to test your logic or simply write your reflections and proofs of execution (e.g. running terminal commands with `!`).

# %%
# Start working here...
