# %% [markdown]
# # Day 15: Phase 1 Retrospective
#
# **Phase 1: Foundations & Infrastructure**
#
# ## Objective
# Retrospectiva de Fase 1 + preparación de Fase 2
#
# ## Task
# Revisar todos los entregables de Fase 1: ¿repos limpio? ¿datos descargados y documentados? ¿web funcionando? ¿pipelines operativos? Identificar gaps. Crear plan personal para Fase 2. Hacer commit limpio con tag `v0.1-foundations`.
#
# **Deliverable:** Tag de release en GitHub + checklist de Fase 1 completado + plan de Fase 2.
#
# ---
#
# ### Instructions:
# *Treat this as your course workbook. Write your code, notes, or execution steps below.*
#
# Remember:
# - Document your decisions.
# - Use clear variable names.
# - If today's task involves creating a script in `src/`, a dashboard in `apps/`, or documentation in `docs/`, you can use this notebook to test your logic or simply write your reflections and proofs of execution (e.g. running terminal commands with `!`).

# %%
# Start working here...
