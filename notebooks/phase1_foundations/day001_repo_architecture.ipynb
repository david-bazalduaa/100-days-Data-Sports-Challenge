# %% [markdown]
# # Day 1: Repo Architecture
#
# **Phase 1: Foundations & Infrastructure**
#
# ## Objective
# Arquitectura del repositorio mono-repo profesional
#
# ## Task
# Crear estructura completa del repo: `data/raw/`, `data/processed/`, `notebooks/`, `src/`, `models/`, `reports/`, `docs/`, `web/`. Configurar `.gitignore` para datos pesados, crear `pyproject.toml` con dependencias, escribir `Makefile` con targets `setup`, `data`, `train`, `test`. Inicializar `environment.yml`.
#
# **Deliverable:** Repo con estructura profesional, README esqueleto, Makefile funcional, primer commit con convención.
#
# ---
#
# ### Instructions:
# *Treat this as your course workbook. Write your code, notes, or execution steps below.*
#
# Remember:
# - Document your decisions.
# - Use clear variable names.
# - If today's task involves creating a script in `src/`, a dashboard in `apps/`, or documentation in `docs/`, you can use this notebook to test your logic or simply write your reflections and proofs of execution (e.g. running terminal commands with `!`).

# %%
# Start working here...
