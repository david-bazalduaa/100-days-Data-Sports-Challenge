# %% [markdown]
# # Day 3: Progress Tracker
#
# **Phase 1: Foundations & Infrastructure**
#
# ## Objective
# Diseñar tracker de progreso interactivo en la web
#
# ## Task
# Implementar en la página web un tracker de los 100 días: tabla o grid con estado (pendiente/en-progreso/completado), enlace al entregable, y barra de progreso general. Puede ser una tabla Markdown auto-generada o un componente HTML/JS ligero.
#
# **Deliverable:** Página `/roadmap` con tracker visual de 100 días, actualizable.
#
# ---
#
# ### Instructions:
# *Treat this as your course workbook. Write your code, notes, or execution steps below.*
#
# Remember:
# - Document your decisions.
# - Use clear variable names.
# - If today's task involves creating a script in `src/`, a dashboard in `apps/`, or documentation in `docs/`, you can use this notebook to test your logic or simply write your reflections and proofs of execution (e.g. running terminal commands with `!`).

# %%
# Start working here...
