# %% [markdown]
# # Day 37: xG Model: Logistic Baseline
#
# ## Objective
# Train logic regression xG. Evaluate Brier score / log loss.
#
# ## Instructions
# 1.
# 2.
#
# --- *Your code below* ---

# %%
# Your code here
