# %% [markdown]
# # Day 46: Probabilistic evaluation: RPS and betting analysis
#
# **Phase 3: Predictive Modeling**
#
# ## Objective
# Probabilistic evaluation: RPS and betting analysis
#
# ## Task
# Implement Ranked Probability Score (RPS) to evaluate result model. Compare model probabilities against market odds. Does the model find value?
#
# **Deliverable:** Notebook day046_rps_and_odds_analysis.ipynb with model vs market comparison.
#
# ---
#
# ### Instructions:
# *Treat this as your course workbook. Write your code, notes, or execution steps below.*
#
# Remember:
# - Document your decisions.
# - Use clear variable names.
# - If today's task involves creating a script in `src/`, a dashboard in `apps/`, or documentation in `docs/`, you can use this notebook to test your logic or simply write your reflections and proofs of execution (e.g. running terminal commands with `!`).

# %%
# Start working here...
