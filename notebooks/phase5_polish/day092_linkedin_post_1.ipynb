# %% [markdown]
# # Day 92: LinkedIn Post 1
#
# **Phase 5: Portfolio Polish & Branding**
#
# ## Objective
# LinkedIn post #1: Insight técnico de un proyecto
#
# ## Task
# Escribir post para LinkedIn con un insight técnico específico de uno de tus proyectos (ej: "Descubrí que el ángulo de tiro es más predictivo que la distancia para xG"). Incluir visualización, 2-3 párrafos técnicos pero accesibles, link al proyecto.
#
# **Deliverable:** Post de LinkedIn publicado + screenshot para el journal.
#
# ---
#
# ### Instructions:
# *Treat this as your course workbook. Write your code, notes, or execution steps below.*
#
# Remember:
# - Document your decisions.
# - Use clear variable names.
# - If today's task involves creating a script in `src/`, a dashboard in `apps/`, or documentation in `docs/`, you can use this notebook to test your logic or simply write your reflections and proofs of execution (e.g. running terminal commands with `!`).

# %%
# Start working here...
