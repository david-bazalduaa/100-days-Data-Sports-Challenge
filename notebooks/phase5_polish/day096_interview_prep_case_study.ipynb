# %% [markdown]
# # Day 96: Interview Prep Case Study
#
# **Phase 5: Portfolio Polish & Branding**
#
# ## Objective
# Preparación de entrevistas — case study walkthrough
#
# ## Task
# Preparar walkthrough de 15 minutos de tu mejor proyecto: slide-by-slide narrative (problema → datos → approach → modelo → resultados → limitaciones → next steps). Practicar explicación oral. Grabarte si es posible.
#
# **Deliverable:** Slides o script de walkthrough + notas de práctica.
#
# ---
#
# ### Instructions:
# *Treat this as your course workbook. Write your code, notes, or execution steps below.*
#
# Remember:
# - Document your decisions.
# - Use clear variable names.
# - If today's task involves creating a script in `src/`, a dashboard in `apps/`, or documentation in `docs/`, you can use this notebook to test your logic or simply write your reflections and proofs of execution (e.g. running terminal commands with `!`).

# %%
# Start working here...
